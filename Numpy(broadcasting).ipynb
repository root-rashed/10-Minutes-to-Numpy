# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1 = np.array([6,7,8,9,10])

# %%
arr1
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
arr+arr1
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
arr+100
# Out:
# array([101, 102, 103, 104, 105])

# %% [markdown]
# Broadcasting

# %%
arr2 = np.array([1,2,3])
arr3 = np.array([[4],[5],[6]])

# %%
arr2+arr3
# Out:
# array([[5, 6, 7],
#        [6, 7, 8],
#        [7, 8, 9]])
