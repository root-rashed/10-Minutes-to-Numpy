# %%
import numpy as np

# %%
from numpy.random import Generator as gen

# %%
from numpy.random import PCG64 as pcg

# %%
arr = gen(pcg())

# %%
arr
# Out:
# Generator(PCG64) at 0x7E86800311C0

# %% [markdown]
# Normal distribution

# %%
arr.normal(size=(5,5))
# Out:
# array([[-0.34241309,  0.66994114, -0.71606264,  0.61080776, -0.5128458 ],
#        [-0.17020896, -1.100316  ,  0.23945849,  1.65415329,  0.19258022],
#        [ 0.63139482, -1.38925087,  1.8225558 ,  0.34952556, -0.38846488],
#        [-0.7710516 , -0.55461984,  0.57834468, -1.0360914 ,  0.88952144],
#        [ 0.20916315,  2.71738363,  1.52020649,  2.08907137, -0.35105962]])

# %% [markdown]
# Integer

# %%
arr = gen(pcg(seed=1000))
arr.integers(low = 100,high = 10000000,size=(10,10))
# Out:
# array([[2037279, 5213905, 8484227, 6038458, 8185432, 4709470, 2086906,
#         2032559, 5029574, 5287637],
#        [2964912, 1910443, 4995003, 2815527, 2614213, 7536840, 1867869,
#         5516762,    7749, 8637234],
#        [8978228, 8053741, 6907922, 2483801, 7934132, 1898655, 6353728,
#         9839957, 1517600, 6700004],
#        [1188335, 2803900, 4292865, 2039211, 9028190, 6250684, 8559857,
#         6526077, 3732430, 8988085],
#        [4626033, 9747640, 8077580, 1539408, 6989409, 6990922, 8126570,
#         4472469, 3522923,  175230],
#        [8483334, 2910319, 9860054, 3812427, 7388867, 3210347, 1288941,
#         9425452,  177058, 7026699],
#        [1172340, 1364589, 2265405, 3432156, 6767816, 8119964, 9083998,
#         1485025, 8401597,  593350],
#        [1629986, 3144234, 4770161, 4201622, 7330758, 8080196, 5781045,
#           95174, 2000042, 4540892],
#        [5638864, 5586913, 7497829,   28986, 2197173, 2977645,   87573,
#          538085, 7132730, 5676730],
# ...
